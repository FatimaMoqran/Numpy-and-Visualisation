# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2,10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]

# %% [markdown]
# ### Pyplot

# %%
#attention toujours avoir les mêmes dimensions
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
#ajouts de paramètres:c : couleurs, lw = épaisseur, ls = style
plt.plot(x,y, c= 'red',lw=4, ls='--')
plt.show()

# %% [markdown]
# ### cycle de vie d'une figure

# %%
#début de la figure
plt.figure()
#contenu de la figure
plt.plot(x,y, label= 'quadratique')
plt.plot(x,x**3, label ='cubique')
##on peut ajouter un titre
plt.title('figure1')
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.legend()
#affiche la figure
plt.show()
#enregistrer notre figure
plt.savefig('figure.png') 

#faire une autre figure
plt.figure()
plt.plot(x,y)

# %%
## subplot grille de graphiques plt.subplot(lignes, colonnes, poisition)
plt.subplot(2,1,1)
plt.plot(x,y,c='red')
plt.subplot(2,1,2)
plt.plot(x,y,c='blue')

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,y)
plt.title('graphique 1')
plt.subplot(2,2,2)
plt.plot(x,np.sin(x),label='sinus')
plt.plot(x,np.cos(x),label='cosinus')
plt.title('graphique 2')
plt.legend()
plt.show()

# %% [markdown]
# ## façon orientée objet

# %%
#permet de creer des figures qui partagent la même absisse
#fig est un objet et ax est un tableau ndarray qui contient des objets
fig, ax = plt.subplots(2,1,sharex=True)
ax[0].plot(x,y)
ax[1].plot(x,np.sin(x))
plt.show()

# %% [markdown]
# ### Experience

# %%
dataset = {f"experience {i}": np.random.randn(100)for i in range(4)}
dataset
# Out:
# {'experience 0': array([-0.06856895, -0.26580883, -0.61718705,  0.641903  , -1.04720502,
#         -0.42329892,  0.02775094,  0.51763108,  1.1160633 , -1.09940471,
#          1.1432836 , -0.11137144,  0.47932429,  0.26291949,  0.00519111,
#         -0.11256918,  2.24548761, -0.70444742,  0.1496742 , -0.09890202,
#          0.08172617, -0.39929928,  0.78187982, -0.32791004, -0.62630143,
#          0.30488632,  0.34385616, -1.7887035 , -0.06794834,  0.44907104,
#         -0.71753379,  0.877288  , -0.80246185,  1.20354773,  0.48638863,
#         -0.41308045, -2.2379996 ,  1.08923431, -0.89537123,  0.10719598,
#         -0.35872183, -1.59698643,  1.68648465, -1.18191392, -2.05213996,
#         -1.1022895 , -0.4325114 , -0.48630156, -0.44388128,  0.43159511,
#         -1.54721265, -1.00570873,  0.27404519,  1.00754102,  0.67183483,
#          1.74336991, -0.33253248, -1.08404959, -0.56289649, -2.62287077,
#         -1.45455458,  0.78551259, -0.46786254, -0.46415385,  0.00697708,
#         -0.58275774,  1.00398698,  0.59657648,  0.10940092, -0.11284307,
#         -0.67823311,  2.17562807, -0.24959695, -0.65865615,  0.32849167,
#         -0.22959645, -1.35870724, -0.17532954, -0.10624526, -0.06220393,
#         -0.03936812, -1.45376438,  0.65944617,  0.44494116, -0.07333579,
#         -0.54707612,  0.99596236, -0.91984677, -0.33868877,  1.16186691,
#          1.55396253,  0.4846294 ,  1.05655382,  2.34620231, -1.11894359,
#          1.56030049, -0.93742102,  0.79244634,  0.26051216, -0.33229557,
#         -1.26748289, -0.66255305, -1.19229869, -0.01529366, -0.15584275,
#         -0.55707585,  0.92074614, -1.18210543, -0.45787714,  0.69681515,
#         -1.63019384, -0.96248649, -1.39011625, -1.38800421,  0.54477807,
#         -0.18541207, -0.87568469,  0.06344534, -0.50370692,  0.33202422]),
#  'experience 3': array([-0.02577017, -1.0308299 ,  1.67829233,  1.85435828, -0.34062791,
#          0.29191517, -0.40530247,  0.54646437, -0.37464047, -0.26413782,
#         -0.93438275,  0.02265176, -0.60002261,  0.6659236 ,  2.12697542,
#         -1.53704154,  1.02779971, -0.99867952, -1.11245416,  1.89119693,
#         -0.52265889, -1.20552973, -1.12641666,  0.96577367,  0.34630395,
#          0.15660432,  0.30887875,  0.49735432, -0.23557226, -1.64272107,
#          0.23988705, -0.8297443 , -2.04912849, -2.90576672,  1.69176429,
#          1.05467071, -0.92514046, -0.62212469,  0.98050097, -0.66543091,
#         -0.43095783,  1.5017605 , -0.10550305,  1.58002064, -2.09242036,
#          0.24955827,  0.70994212, -0.87953277,  1.36591069, -0.50125896,
#         -0.97273647,  0.15182707,  1.18109844, -0.53957243, -0.6173954 ,
#          0.08445294, -0.62761483, -0.8738011 ,  0.74727594, -0.09399032,
#          0.46229077, -0.22076238, -0.31073967, -0.47219601,  1.22836145,
#         -0.71992774, -2.23364186, -1.27342425, -0.20620126,  1.65766236,
#          0.6859667 , -0.90553205, -0.32213015,  2.21535214,  0.58942746,
#          1.42215416,  0.34367299, -0.21960699, -0.9266749 ,  1.46581355,
#         -1.72065884, -0.16848484,  0.81341319,  3.07636974,  0.00925123,
#          0.13061789, -0.36785622,  0.82150621,  0.0821612 , -0.83966314,
#         -0.69091598, -1.21560568,  1.63219074,  1.14082062, -0.54477147,
#         -0.53909976, -1.74663133,  0.40718622,  0.89181928, -0.10854849])}

# %% [raw]
# for k, v in dataset.items():
#     print(k)

# %%
n = len(dataset)
plt.figure(figsize = (12,8))
for k,i in zip(dataset.keys(),range(1,n+1)):
    plt.subplot(n,1,i)
    plt.plot(dataset[k])
    plt.title(k)
plt.show()

# %%
def graphique(data):
    #le nombre d'experiences que l'on veut
    n = len(data)
    plt.figuresize(12,8)
    for k , i in zip(data.keys(), range(1,n+1)):
        plt.subplot(n,1,i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()
